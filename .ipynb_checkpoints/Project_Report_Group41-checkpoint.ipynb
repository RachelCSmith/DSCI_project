# %% [markdown]
# ### Title: Predicting Cleveland Heart Disease

# %% [markdown]
# #### Group 41 - DSCI100 Project Report - Rachel Smith, Emily Han, Selina Zhou, Junyue Xue

# %% [markdown]
# #### **1. Introduction**
#
# Scientists aim to predict the presence of heart disease based on various medical attributes. This helps patients with heart disease receive proper treatment, and minimizes the costly resources used on healthy patients. Thus, this project investigates the question: "can age, serum cholesterol, and resting blood pressure measurements predict the presence of heart disease for males?" We will use the Heart Disease dataset, which contains 14 medical attributes for 303 individuals in Cleveland. The num column indicates presence (categories 1-4) or absence (category 0) of heart disease, with 1-4 referring to different diseases. This project will combine categories 1-4 to focus on presence vs absence, as some diseases are extremely rare (leading to very unbalanced data). Once heart disease is detected, patients can receive further treatment to determine their specific disease.

# %% [markdown]
# #### **2. Methods & Results**
#
# ##### **2.1. Loading Data**
#
# We begin by downloading and tidying the Heart Disease dataset. Column names are assigned for readability, and factor columns are used for categorical variables. For clarity, Table 1 shows the first 6 rows of the 303 row tibble.

# %%
library(tidyverse)
library(repr)
library(tidymodels)

url<-"https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
download.file(url,"cleveland_heart_disease.csv")
cleveland_data<-read_csv("cleveland_heart_disease.csv",col_names=FALSE)|>
rename(age=X1,sex=X2,cp=X3,trestbps=X4,chol=X5,fbs=X6,restecg=X7,thalach=X8,exang=X9,oldpeak=X10,slope=X11,ca=X12,thal=X13,num=X14)|>
    mutate(across(sex:cp,as_factor))|>
    mutate(across(fbs:restecg,as_factor))|>
    mutate(exang=as_factor(exang),slope=as_factor(slope),thal=as_factor(thal),num=as_factor(num))
head(cleveland_data)
# Out:
# Rows: 303 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): X12, X13
# dbl (12): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   age sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca  thal num
# 1 63  1   1  145      233  1   2       150     0     2.3     3     0.0 6.0  0
# 2 67  1   4  160      286  0   2       108     1     1.5     2     3.0 3.0  2
# 3 67  1   4  120      229  0   2       129     1     2.6     2     2.0 7.0  1
# 4 37  1   3  130      250  0   0       187     0     3.5     3     0.0 3.0  0
# 5 41  0   2  130      204  0   2       172     0     1.4     1     0.0 3.0  0
# 6 56  1   2  120      236  0   0       178     0     0.8     1     0.0 3.0  0

# %% [markdown]
# Column information for Table 1 is as follows:
# * `age`: age of the patient (years)
# * `sex`: sex (1=male, 0=female)
# * `cp`: chest pain type (1=typical angina, 2=atypical angina, 3=non-anginal pain, 4=asymptomatic)
# * `trestbps`: resting blood pressure, upon admission to hospital (mm Hg)
# * `chol`: serum cholestoral (mg/dl)
# * `fbs`: fasting blood sugar > 120 mg/dl (1=true, 0=false)
# * `restecg`: resting electrocardiographic results (0=normal, 1=having abnormality, 2=showing left ventricular hypertrophy)
# * `thalach`: maximum heart rate achieved
# * `exang`: exercise induced angina (1=yes, 0=no)
# * `oldpeak`: ST depression induced by exercise relative to rest
# * `slope`: slope of the peak exercise ST segment (1=upsloping, 2=flat, 3=downsloping)
# * `ca`: number of major vessels colored by fluoroscopy
# * `thal`: 3=normal, 6=fixed defect, 7=reversable defect
# * `num`: diagnosis of heart disease (0=absence, 1,2,3,4=presence)

# %% [markdown]
# ##### **2.2. Choosing Predictors, Filtering Data, and Balancing Data**

# %% [markdown]
# INSERT PREDICTOR JUSTIFICATION
#
# Below, this information is used to filter the data. Sex is filtered for males, and the predictor columns age, chol, and trestbps (resting blood pressure) are selected alongside num (classification of heart rate diagnosis). The selected predictor columns contain no missing values. Further, categories 1-4 in the num column are combined to represent if heart disease is "present", and category 0 is renamed to "absent" for clarity.

# %%
filtered_data<-cleveland_data|>
    filter(sex==1)|>
    select(age,chol,trestbps,num)|>
    mutate(num=fct_recode(num,"Present"="1","Present"="2","Present"="3","Present"="4","Absent"="0"))
head(filtered_data)

summary_table<-filtered_data|>
    group_by(num)|>
    summarize(count=n())
summary_table
# Out:
#   age chol trestbps num
# 1 63  233  145      Absent
# 2 67  286  160      Present
# 3 67  229  120      Present
# 4 37  250  130      Absent
# 5 56  236  120      Absent
# 6 63  254  130      Present
#   num     count
# 1 Absent   92
# 2 Present 114

# %% [markdown]
# Table 2 shows the first 6 rows of the filtered dataset, while Table 3 shows a summary table of the distribution of absent and present cases. Notably, this distribution is uneven, with a count of 114 and 92 for present and absent cases, respectively. This could create a biased prediction, as the K-nearest neighbor algorithm uses the classification of surrounding points to predict new points, meaning the algorithm will more likely pick the class which has more points.  Thus, below we balance the data to create a more accurate classification  model (Timbers et al., 2022).

# %%
#Balancing the Data 
install.packages("themis")
library(themis) 
install.packages("kknn")
library(kknn)

balance_recipe <- recipe(num ~., data = filtered_data) |> 
step_upsample(num, over_ratio = 1, skip = FALSE) |> 
prep() 

upsampled_cleveland <- bake(balance_recipe, filtered_data)
upsampled_cleveland |> 
group_by(num) |> 
summarize(n = n())
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#   num     n
# 1 Absent  114
# 2 Present 114

# %% [markdown]
# Table 3 shows the upsampled dataset's distribution of absent and present cases. Notably, both cases are equally present at 114 cases, showing the data has been balanced.

# %% [markdown]
# ##### **2.3. Splitting the Data**

# %% [markdown]
# Data will be split into a training and testing data, with training data being used to develop the classification model. Specifically, we split our data into training and testing data using a 75% and 25% split, respectively. We choose this split as it is an appropriate percent tradeoff for wanting to use a larger training data set to train an accurate model, while also needing a larger test data set to get an accurate performance evaluation (Timbers et al., 2022).
#
# We begin by setting the seed in order to have reproducibility in our data, so we get the same result each time the code is run (Timbers et al., 2022)

# %%
set.seed(9)
data_split<-initial_split(upsampled_cleveland,prop=0.75,strata=num)
data_train<-training(data_split)
data_test<-testing(data_split)
head(data_train)

distribution_num<-data_train|>
    group_by(num)|>
    summarize(count=n())
distribution_num
# Out:
#   age chol trestbps num
# 1 52  201  134      Absent
# 2 45  260  115      Absent
# 3 48  245  130      Absent
# 4 56  193  120      Absent
# 5 44  235  140      Absent
# 6 66  228  160      Absent
#   num     count
# 1 Absent  85
# 2 Present 85

# %% [markdown]
# Table 4 shows the first 6 rows of the training data, while Table 5 shows its distribution of absent and present cases. Notably, creating training data from the upsampled dataset has resulted in balanced absent and present cases in the training data, as well.

# %% [markdown]
# ##### **2.4. Method and Exploratory Data Analysis**

# %% [markdown]
# Our data analysis will use the KNN classification method. The predicted attribute will be whether heart disease is "present" or "absent" in the patient. The predictors will include age, chol (serum cholesterol (mg/dl)), and trestbps (resting blood pressure). They're most directly associated with heart disease as described in the introduction, and are numerical values (not categorical) that can be used with KNN. This will allow us to take a new observation, plot it against the training data, and predict the type of heart disease depending on the mode classification of the K-nearest neighbors. One way we’ll visualize the results is using a scatter plot with two predictors on the x and y axes, and points coloured by presence or absence of heart disease.
#
# For exploratory analysis, Table 6 shows the average of all three predictors for absent and present cases. The difference in values for each predictor further justifies the use of these variables in classifying heart disease. It also suggests that we expect present cases to be found in patients with higher age, serum cholesterol, and resting blood pressure.

# %%
mean_predictors<-data_train|>
    group_by(num)|>
    summarize(avg_age=mean(age),avg_chol=mean(chol),avg_trestbps=mean(trestbps))
mean_predictors
# Out:
#   num     avg_age  avg_chol avg_trestbps
# 1 Absent  49.75294 233.0706 126.9647
# 2 Present 56.40000 246.7294 130.9765

# %% [markdown]
# Further, Figures 1-3 show the separate distribution of each predictor for present and absent cases. This visualizes the trend suggested by Table 6, in that we expect present cases to be found in patients with higher age, serum cholesterol, and resting blood pressure.

# %%
options(repr.plot.width = 5.5, repr.plot.height = 6)
graph_age<-data_train|>
    ggplot(aes(x=age,fill=num))+
        geom_histogram()+
    facet_grid(rows=vars(num))+
    labs(x="Age",fill="Heart Disease Diagnosis",caption="test")+
    ggtitle("Distribution of Heart Disease Diagnosis by Age")
graph_age

graph_chol<-data_train|>
    ggplot(aes(x=chol,fill=num))+
        geom_histogram()+
    facet_grid(rows=vars(num))+
     labs(x="Serum Cholesterol (mg/dl)",fill="Heart Disease Diagnosis")+
    ggtitle("Distribution of Heart Disease Diagnosis by Serum Cholesterol")
graph_chol

graph_thalach<-data_train|>
    ggplot(aes(x=trestbps,fill=num))+
        geom_histogram()+
    facet_grid(rows=vars(num))+
     labs(x="Resting Blood Pressure",fill="Heart Disease Diagnosis")+
    ggtitle("Distribution of Heart Disease Diagnosis \nby Resting Heart Rate")
graph_thalach
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# ##### **2.5. Expected Outcomes and Significance**
#
# Our model aims to predict whether an individual has heart disease using age, cholesterol, and trestbp measurements. Considering the distributions, we expect older individuals (around high 50s) with higher cholesterol (around 250 mg/dl) and higher resting blood pressure around 140 bps to have heart disease, and younger individuals with lower cholesterol and resting blood pressure to be absent of heart disease. These findings give doctors more insight and evidence into trends for heart diseases, which reduces misdiagnoses. This may also decrease the time required for diagnoses, minimizing opportunities for the disease to worsen. This allows patients with heart diseases to receive proper treatment in a timely manner, lengthening their lives. It also reduces the resources which are unnecessarily used on healthy patients. Findings could lead to further questions, including “could high cholesterol and resting blood pressure be indications of other medical problems as well?” Followup investigations could also include whether treatments like lowering cholesterol or raising thalach may help reduce risks of heart disease.

# %% [markdown]
# ##### **2.6.1 Building the Model: Choosing K**
#
# Using the training data, we create a model with 'num' as the classification column and age, chol, and trestbps as predictors. Predictors are standardized to ensure one predictor is not weighed more heavily in the model, as K-nearest neighbors uses Euclidean distance and predictors are currently of different scales. Following, cross-validation of the accuracies of different values of K (1, 6, 11..., 96) is used to choose a K value.

# %%
#Standardizing the data 
cleveland_recipe <- recipe(num ~., data = data_train)|> 
step_scale(all_predictors()) |> 
step_center(all_predictors()) 

#Creating the specification model
knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
set_engine("kknn") |> 
set_mode("classification") 

#Cross Validation
set.seed(9)
cleveland_vfold <- vfold_cv(data_train, v = 10, strata = num) 

#K values to test
k_vals <- tibble(neighbors = seq(from = 1, to = 100, by = 5)) 

#Tuning the model for each value of K
knn_results <- workflow() |> 
add_recipe(cleveland_recipe) |> 
add_model(knn_spec) |> 
tune_grid(resamples = cleveland_vfold, grid = k_vals) |> 
collect_metrics() 

#Accuracies for each K value
accuracies <- knn_results |> 
filter(.metric == "accuracy") 

#Plot of K value vs. accuracy estimate, used for choosing K
accuracy_vs_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) + 
geom_point() + 
geom_line() + 
labs(x = "Neighbors", y = "Accuracy Estimate") + 
theme(text = element_text(size = 12)) 

accuracy_vs_k
# Out:
# plot without title

# %%
new_spec<-nearest_neighbor(weight_func = "rectangular", neighbors = 36) |> 
set_engine("kknn") |> 
set_mode("classification")

new_results <- workflow() |> 
add_recipe(cleveland_recipe) |> 
add_model(new_spec) |> 
fit(data=data_train)

cleveland_test_predictions<-predict(new_results,data_test)|>
    bind_cols(data_test)
cleveland_test_predictions

cleveland_test_predictions|>
    metrics(truth=num,estimate=.pred_class)|>
    filter(.metric=="accuracy")

confusion <- cleveland_test_predictions |>
             conf_mat(truth = num, estimate = .pred_class)
confusion
# Out:
#    .pred_class age chol trestbps num
# 1  Present     51  261  140      Absent
# 2  Present     59  212  150      Absent
# 3  Absent      51  245  125      Absent
# 4  Absent      51  213  125      Absent
# 5  Absent      52  223  138      Absent
# 6  Absent      39  321  140      Absent
# 7  Absent      40  199  140      Absent
# 8  Absent      56  221  130      Absent
# 9  Present     70  245  156      Absent
# 10 Present     55  262  130      Absent
# 11 Absent      44  220  120      Absent
# 12 Present     65  177  120      Absent
# 13 Absent      53  246  130      Absent
# 14 Present     66  302  120      Absent
# 15 Absent      58  211  140      Absent
# 16 Absent      42  226  140      Absent
# 17 Absent      56  240  120      Absent
# 18 Absent      48  222  122      Absent
# 19 Absent      57  126  150      Absent
# 20 Absent      54  239  140      Absent
# 21 Present     55  262  130      Absent
# 22 Absent      29  204  130      Absent
# ...

# %%
visual_recipe<-recipe(.pred_class~age+chol+trestbps,data=cleveland_test_predictions)|>
    step_scale(all_predictors()) |>
    step_center(all_predictors()) |>
    prep()

visual_data<-bake(visual_recipe,cleveland_test_predictions)
head(visual_data)
# Out:
#   age        chol       trestbps   .pred_class
# 1 -0.2571233  0.5000703  0.3496106 Present
# 2  0.5713851 -0.6872312  0.9306253 Absent
# 3 -0.2571233  0.1123801 -0.5219115 Absent
# 4 -0.2571233 -0.6630005 -0.5219115 Absent
# 5 -0.1535597 -0.4206941  0.2334076 Absent
# 6 -1.4998859  1.9539090  0.3496106 Absent

# %%
options(repr.plot.height=4,repr.plot.width=6)
age_chol_plot <- visual_data |>
  ggplot(aes(x = age, y = chol, color = .pred_class)) +
  geom_point(alpha = 0.5) +
  labs(x = "Age (standardized)", 
       y = "Serum Cholesterol (standardized)",
       color = "Heart Disease Diagnosis") +
ggtitle("Figure X: Age vs. Serum Cholesterol")+
  scale_color_manual(values = c("orange2", "steelblue2")) +
  theme(text = element_text(size = 12))
age_chol_plot

age_trestbps_plot <- visual_data |>
  ggplot(aes(x = age, y = trestbps, color = .pred_class)) +
  geom_point(alpha = 0.5) +
  labs(x = "Age (standardized)", 
       y = "Resting Blood Pressure (standardized)",
       color = "Heart Disease Diagnosis") +
ggtitle("Figure X: Age vs. Resting Blood Pressure")+
  scale_color_manual(values = c("orange2", "steelblue2")) +
  theme(text = element_text(size = 12))
age_trestbps_plot

chol_trestbps_plot <- visual_data |>
  ggplot(aes(x = chol, y = trestbps, color = .pred_class)) +
  geom_point(alpha = 0.5) +
  labs(x = "Serum Cholesterol (standardized)", 
       y = "Resting Blood Pressure (standardized)",
       color = "Heart Disease Diagnosis") +
ggtitle("Figure X: Serum Cholesterol vs. Resting Blood Pressure")+
  scale_color_manual(values = c("orange2", "steelblue2")) +
  theme(text = element_text(size = 12))
chol_trestbps_plot
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### **References**
